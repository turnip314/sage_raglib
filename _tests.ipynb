# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helpers import *
from msolve import *
from multi_modular import *
from raglib import *
from subroutines import *

# %% [markdown]
# # Groebner Tests

# %%
R.<x1,x2,x3,x4,x5,x6> = QQ[]

F = [
    x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1,
    x1**2 + 2*x2**2 + 2*x3**2 + 2*x4**2 + 2*x5**2 + 2*x6**2 - x1,
    2*x1*x2 + 2*x2*x3 + 2*x3*x4 + 2*x4*x5 + 2*x5*x6 - x2,
    x2**2 + 2*x1*x3 + 2*x2*x4 + 2*x3*x5 + 2*x4*x6 - x3,
    2*x2*x3 + 2*x1*x4 + 2*x2*x5 + 2*x3*x6 - x4,
    x3**2 + 2*x2*x4 + 2*x1*x5 + 2*x2*x6 - x5,
]
vars_list = [x1, x2, x3, x4, x5, x6]

roots = MSolveRealRoots(F, [x1,x2,x3,x4,x5,x6], []); roots[1][0]
# Out:
# {x1: [0.520469534619619?, 0.520469534619619?],
#  x2: [0.0733443820953735?, 0.0733443820953735?],
#  x3: [0.0951573445363090?, 0.0951573445363090?],
#  x4: [0.1303625630224671?, 0.1303625630224671?],
#  x5: [0.1844778451963342?, 0.1844778451963342?],
#  x6: [-0.2435769021602928?, -0.2435769021602928?]}

# %%
gb = MSolveGroebner(F, 0, [x1,x2,x3,x4,x5,x6]); len(gb)
# Out:
# 22

# %%
gb[0]
# Out:
# x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1

# %%
# NOT WORKING RIGHT NOW
R = PolynomialRing(QQ, ['x', 'y'], order='degrevlex')
x, y = R.gens()
result = SaturateIntersectMSolve(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y],
    vs=[x, y],
); result
# Out:
# gb: [1]
# lmgb: [1]
# lm: [1]

# %%
# NOT WORKING RIGHT NOW
R = PolynomialRing(QQ, ['x', 'y'], order='degrevlex')
x, y = R.gens()
result = SaturateIntersectMSolve(
    eqs1=[x**3 * (x-y)*(y - 2)^2],
    pol=x,
    eqs2=[],
    vs=[x, y],
); result
# Out:
# [x, y^3 - 4*y^2 + 4*y]

# %%
result = SaturateIntersect(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 1],
    vs=[x, y],
); result
# Out:
# [y - 2, y - 1, x]

# %% [markdown]
# # Subroutines Test

# %%
SemiAlgebraicSolve([], [x*y], [x*y*z])
# Out:
# [{x: [-0.50000000000000000?, -0.50000000000000000?],
#   z: [1, 1],
#   y: [-0.50000000000000000?, -0.50000000000000000?]},
#  {x: [1/2, 1/2], z: [-1, -1], y: [1/2, 1/2]},
#  {x: [1/2, 1/2], z: [1, 1], y: [1/2, 1/2]},
#  {x: [1.5000000000000000?, 1.5000000000000000?],
#   z: [-1, -1],
#   y: [1.5000000000000000?, 1.5000000000000000?]},
#  {x: [2.822875655532295?, 2.822875655532295?],
#   z: [-1, -1],
#   y: [0.1771243444677047?, 0.1771243444677047?]},
#  {x: [0.1771243444677047?, 0.1771243444677047?],
#   z: [-1, -1],
#   y: [2.822875655532295?, 2.822875655532295?]},
#  {x: [2.732050807568878?, 2.732050807568878?],
#   z: [-1, -1],
#   y: [0.2679491924311227?, 0.2679491924311227?]},
#  {x: [1, 1], z: [-1, -1], y: [2, 2]}]

# %% [markdown]
# # Raglib Tests

# %%
PointsPerComponents([x*y-1], [x^2+y^2-4], [])
# Out:
# [{x: [-0.4841854633561014?, -0.4841854633561014?],
#   y: [-2.065324293440291?, -2.065324293440291?]},
#  {x: [-2.065324293440291?, -2.065324293440291?],
#   y: [-0.4841854633561014?, -0.4841854633561014?]},
#  {x: [2.065324293440291?, 2.065324293440291?],
#   y: [0.4841854633561014?, 0.4841854633561014?]},
#  {x: [0.4841854633561014?, 0.4841854633561014?],
#   y: [2.065324293440291?, 2.065324293440291?]},
#  {x: [-0.2559980601477473?, -0.2559980601477473?],
#   y: [-3.906279600020632?, -3.906279600020632?]},
#  {x: [-3.906279600020632?, -3.906279600020632?],
#   y: [-0.2559980601477473?, -0.2559980601477473?]},
#  {x: [2.137775255856462?, 2.137775255856462?],
#   y: [0.4677760196075279?, 0.4677760196075279?]},
#  {x: [0.4677760196075279?, 0.4677760196075279?],
#   y: [2.137775255856462?, 2.137775255856462?]},
#  {x: [-0.2284623446800520?, -0.2284623446800520?],
#   y: [-4.377088930783937?, -4.377088930783937?]},
#  {x: [-4.377088930783937?, -4.377088930783937?],
#   y: [-0.2284623446800520?, -0.2284623446800520?]}]

# %%
PointsPerComponents([], [], [x,y])
# Out:
# [{y: [1, 1], x: [-1, -1]},
#  {y: [1, 1], x: [1, 1]},
#  {x: [1/2, 1/2], y: [0.50000000000000000?, 0.50000000000000000?]},
#  {x: [-1/4, -1/4], y: [-0.25000000000000000?, -0.25000000000000000?]},
#  {x: [1/2, 1/2], y: [-0.50000000000000000?, -0.50000000000000000?]},
#  {x: [-1/4, -1/4], y: [0.25000000000000000?, 0.25000000000000000?]}]

# %%
PointsPerComponents([], [x], [x,y])
# Out:
# [{y: [1, 1], x: [1, 1]},
#  {x: [1/2, 1/2], y: [0.50000000000000000?, 0.50000000000000000?]},
#  {x: [1/2, 1/2], y: [-0.50000000000000000?, -0.50000000000000000?]}]

# %%
PointsPerComponents([], [], [(x-1)^2+y^2-1, (x+1)^2+y^2-1-1/2^32])
# Out:
# [{x: [-1, -1], y: [-3, -3]},
#  {x: [-1, -1], y: [0, 0]},
#  {x: [-1, -1], y: [3, 3]},
#  {x: [1, 1], y: [-2, -2]},
#  {x: [1, 1], y: [0, 0]},
#  {x: [1, 1], y: [2, 2]},
#  {x: [3, 3], y: [0, 0]},
#  {x: [-4, -4], y: [0, 0]},
#  {x: [2, 2], y: [-1, -1]},
#  {x: [2, 2], y: [1, 1]},
#  {x: [1/17179869184, 1/17179869184], y: [0, 0]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [-0.7071067812688656?, -0.7071067812688656?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [0.7071067812688656?, 0.7071067812688656?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [1.000000000019403?, 1.000000000019403?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [-2.000000000019403?, -2.000000000019403?]},
#  {x: [0.000010789593218788872?, 0.000010789593218788872?], y: [0, 0]},
#  {x: [-0.000010789593218788872?, -0.000010789593218788872?], y: [0, 0]}]

# %%
PointsPerComponents([x+y, x-y], [], [])
# Out:
# [{x: [0, 0], y: [0, 0]}]
