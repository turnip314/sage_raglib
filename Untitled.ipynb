# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers import *
from msolve import *
from multi_modular import *

# %%
R.<x1,x2,x3,x4,x5,x6> = QQ[]

F = [
    x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1,
    x1**2 + 2*x2**2 + 2*x3**2 + 2*x4**2 + 2*x5**2 + 2*x6**2 - x1,
    2*x1*x2 + 2*x2*x3 + 2*x3*x4 + 2*x4*x5 + 2*x5*x6 - x2,
    x2**2 + 2*x1*x3 + 2*x2*x4 + 2*x3*x5 + 2*x4*x6 - x3,
    2*x2*x3 + 2*x1*x4 + 2*x2*x5 + 2*x3*x6 - x4,
    x3**2 + 2*x2*x4 + 2*x1*x5 + 2*x2*x6 - x5,
]
vars_list = [x1, x2, x3, x4, x5, x6]

#MSolveRealRoots(F, [x1,x2,x3,x4,x5,x6], [])

# %%
#MSolveGroebner(F, 0, [x1,x2,x3,x4,x5,x6])

# %%
#_[0]
# Out:
# x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1

# %%
#_.parent()
# Out:
# Multivariate Polynomial Ring in x1, x2, x3, x4, x5, x6 over Rational Field

# %%
R = PolynomialRing(QQ, ['x', 'y'], order='degrevlex')
x, y = R.gens()
result = SaturateIntersectMSolve(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)

# %%
result
# Out:
# [-2*y + 1, x]

# %%
result = SaturateIntersect(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)
# Out:
# Ideal (y - 2) of Multivariate Polynomial Ring in x, y over Rational Field

# %%
result
# Out:
# [y - 2]

# %%
from Raglib import *

# %%
SemiAlgebraicSolve([], [x*y], [x*y*z])
# Out:
# +++++++++
# [{x: [-0.50000000000000000?, -0.50000000000000000?],
#   z: [1, 1],
#   y: [-0.50000000000000000?, -0.50000000000000000?]},
#  {x: [1/2, 1/2], z: [-1, -1], y: [1/2, 1/2]},
#  {x: [1/2, 1/2], z: [1, 1], y: [1/2, 1/2]},
#  {x: [1.5000000000000000?, 1.5000000000000000?],
#   z: [-1, -1],
#   y: [1.5000000000000000?, 1.5000000000000000?]},
#  {x: [2.822875655532295?, 2.822875655532295?],
#   z: [-1, -1],
#   y: [0.1771243444677047?, 0.1771243444677047?]},
#  {x: [0.1771243444677047?, 0.1771243444677047?],
#   z: [-1, -1],
#   y: [2.822875655532295?, 2.822875655532295?]},
#  {x: [2.732050807568878?, 2.732050807568878?],
#   z: [-1, -1],
#   y: [0.2679491924311227?, 0.2679491924311227?]},
#  {x: [1, 1], z: [-1, -1], y: [2, 2]}]

# %%
R.<x,y> = QQ[]
x.variables()[0].parent()
# Out:
# Multivariate Polynomial Ring in x, y over Rational Field

# %%
(x+y).variables()
# Out:
# (x, y)

# %%
from Raglib import *
test(R)
# Out:
# True

# %%
sign(-3)
# Out:
# -1

# %%
def PointsPerComponents(eqs, pos, ineqs, opts={}):
    _l = None
    newopts = None

    is_empty = opts.get("isempty", False)
    
    if not is_empty:
        return SemiAlgebraicSolve(eqs, pos, ineqs, opts);
    else:
        newopts = {
            k: 0 if k == "isempty" else v
            for k, v in opts.items()
        }
        return SemiAlgebraicSolve(eqs, pos, ineqs, newopts);

# %%
PointsPerComponents([x*y-1], [x^2+y^2-4], [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[298], line 1
# ----> 1 PointsPerComponents([x*y-Integer(1)], [x**Integer(2)+y**Integer(2)-Integer(4)], [])
#
# Cell In[209], line 8, in PointsPerComponents(eqs, pos, ineqs, opts)
#       5 is_empty = opts.get("isempty", False)
#       7 if not is_empty:
# ----> 8     return SemiAlgebraicSolve(eqs, pos, ineqs, opts);
#       9 else:
#      10     newopts = {
#      11         k: Integer(0) if k == "isempty" else v
#      12         for k, v in opts.items()
#      13     }
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:1946, in SemiAlgebraicSolve(Equations, Inequalities, Inequations, opts)
#    1944 if len(oldvars) > 0 and "card" not in newopts:
#    1945     new_only = [v for v in newvars if v not in oldvars]
# -> 1946     if pol.degree(new_only) == 1:
#    1947         newopts = {**opts, "newvars": list(set(pol.variables()) | set(oldvars))}
#    1948         if newopts == opts:
#
# TypeError: Argument 'x' has incorrect type (expected sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular, got list)

# %%
PointsPerComponents([], [x], [x*y*z])
# Out:
# ++++++++
# [{z: [1, 1], y: [1, 1], x: [1, 1]},
#  {x: [1, 1], y: [-2, -2], z: [1, 1]},
#  {x: [1/2, 1/2],
#   z: [-0.3138593383654928?, -0.3138593383654928?],
#   y: [-3.186140661634508?, -3.186140661634508?]},
#  {x: [1/2, 1/2],
#   z: [-3.186140661634508?, -3.186140661634508?],
#   y: [-0.3138593383654928?, -0.3138593383654928?]},
#  {x: [1/2, 1/2],
#   z: [0.2655644370746374?, 0.2655644370746374?],
#   y: [-3.765564437074638?, -3.765564437074638?]},
#  {x: [1/2, 1/2],
#   z: [-3.765564437074638?, -3.765564437074638?],
#   y: [0.2655644370746374?, 0.2655644370746374?]},
#  {x: [2.000000000000000?, 2.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [1/2, 1/2],
#   z: [0.7807764064044151?, 0.7807764064044151?],
#   y: [-1.280776406404415?, -1.280776406404415?]},
#  {x: [1/2, 1/2],
#   z: [-1.280776406404415?, -1.280776406404415?],
#   y: [0.7807764064044151?, 0.7807764064044151?]},
#  {x: [5.000000000000000?, 5.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [1/2, 1/2], z: [2, 2], y: [1/2, 1/2]},
#  {x: [1/2, 1/2], z: [1/2, 1/2], y: [2, 2]},
#  {x: [1/2, 1/2],
#   z: [2.850781059358213?, 2.850781059358213?],
#   y: [-0.3507810593582122?, -0.3507810593582122?]},
#  {x: [1/2, 1/2],
#   z: [-0.3507810593582122?, -0.3507810593582122?],
#   y: [2.850781059358213?, 2.850781059358213?]}]

# %%
PointsPerComponents([], [], [(x-1)^2+y^2-1, (x+1)^2+y^2-1-1/2^32])
# Out:
# [{x: [-1, -1], y: [-3, -3]},
#  {x: [-1, -1], y: [0, 0]},
#  {x: [-1, -1], y: [3, 3]},
#  {x: [1, 1], y: [-2, -2]},
#  {x: [1, 1], y: [0, 0]},
#  {x: [1, 1], y: [2, 2]},
#  {x: [3, 3], y: [0, 0]},
#  {x: [-4, -4], y: [0, 0]},
#  {x: [2, 2], y: [-1, -1]},
#  {x: [2, 2], y: [1, 1]},
#  {x: [1/17179869184, 1/17179869184], y: [0, 0]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [-0.7071067812688656?, -0.7071067812688656?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [0.7071067812688656?, 0.7071067812688656?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [1.000000000019403?, 1.000000000019403?]},
#  {x: [1/17179869184, 1/17179869184],
#   y: [-2.000000000019403?, -2.000000000019403?]},
#  {x: [0.000010789593218788872?, 0.000010789593218788872?], y: [0, 0]},
#  {x: [-0.000010789593218788872?, -0.000010789593218788872?], y: [0, 0]}]
