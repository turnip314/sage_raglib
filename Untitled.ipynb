# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers import *
from msolve import *
from multi_modular import *

# %%
R.<x1,x2,x3,x4,x5,x6> = QQ[]

F = [
    x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1,
    x1**2 + 2*x2**2 + 2*x3**2 + 2*x4**2 + 2*x5**2 + 2*x6**2 - x1,
    2*x1*x2 + 2*x2*x3 + 2*x3*x4 + 2*x4*x5 + 2*x5*x6 - x2,
    x2**2 + 2*x1*x3 + 2*x2*x4 + 2*x3*x5 + 2*x4*x6 - x3,
    2*x2*x3 + 2*x1*x4 + 2*x2*x5 + 2*x3*x6 - x4,
    x3**2 + 2*x2*x4 + 2*x1*x5 + 2*x2*x6 - x5,
]
vars_list = [x1, x2, x3, x4, x5, x6]

#MSolveRealRoots(F, [x1,x2,x3,x4,x5,x6], [])

# %%
#MSolveGroebner(F, 0, [x1,x2,x3,x4,x5,x6])

# %%
#_[0]
# Out:
# x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1

# %%
#_.parent()
# Out:
# Multivariate Polynomial Ring in x1, x2, x3, x4, x5, x6 over Rational Field

# %%
R = PolynomialRing(QQ, ['x', 'y'], order='degrevlex')
x, y = R.gens()
result = SaturateIntersectMSolve(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)

# %%
result
# Out:
# [-2*y + 1, x]

# %%
result = SaturateIntersect(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)
# Out:
# Ideal (y - 2) of Multivariate Polynomial Ring in x, y over Rational Field

# %%
result
# Out:
# [y - 2]

# %%
from Raglib import *

# %%
SemiAlgebraicSolve([], [], [x*y*z])
# Out:
# ++++
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 SemiAlgebraicSolve([], [], [x*y*z])
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:2503, in SemiAlgebraicSolve(Equations, Inequalities, Inequations, opts)
#    2500     else:
#    2501         newopts = opts
# -> 2503 newsols = SemiAlgebraicSolveIterateOnFamilies(
#    2504     Equations, _toStudy, Inequalities, Inequations, vs, newopts
#    2505 )
#    2506 midsols = [
#    2507     {R(v): (k[0] + k[1]) / 2 for v, k in pt.items()}
#    2508     for pt in newsols
#    2509 ]
#    2511 lsigns = lsigns | set(
#    2512     tuple(map(sign, [q.subs(pt) for q in Inequations]))
#    2513     for pt in midsols
#    2514 )
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:2273, in SemiAlgebraicSolveIterateOnFamilies(Equations, Families, Inequalities, Inequations, vars, opts)
#    2271 if verb >= 1:
#    2272     print("<", end="")
# -> 2273 newsols = SolveFamily(
#    2274     Equations, pos, nonzero,
#    2275     Inequalities, Inequations, vars, opts
#    2276 )
#    2277 if verb >= 1:
#    2278     print(f":->[ns={len(newsols)}]:", end="")
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:2212, in SolveFamily(Equations, FamPositive, FamNotNull, Inequalities, Inequations, vars, opts)
#    2209     return sols
#    2211 if len(Equations) + len(Fam) < len(vars):
# -> 2212     sols = UnboundedComponents(
#    2213         Equations, FamPositive, FamNotNull, Inequalities, Inequations, vars, opts
#    2214     )
#    2215     if len(sols) > 0 and isempty > 0:
#    2216         return sols
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:1813, in UnboundedComponents(Equations, FamPositive, FamNotNull, Inequalities, Inequations, vars, opts)
#    1811 if verb >= 1:
#    1812     print("[b:", end="")
# -> 1813 hyp, bounds = ComputeBounds(Equations, Fam, Positive, NotNull, vars, opts)
#    1814 if verb >= 1:
#    1815     print(f" -> {hyp}, {bounds}", end="")
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:1138, in ComputeBounds(Equations, Fam, Positive, NotNull, vars, opts)
#    1135     return ComputeBoundsRegular(Equations, Fam, Positive, NotNull, vars,
#    1136                                 hyp, minors, gendeg, opts)
#    1137 else:
# -> 1138     return ComputeBoundsSingular(Equations, Fam, Positive, NotNull, vars,
#    1139                                  hyp, minors, gendeg, lc, opts)
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/Raglib.py:1049, in ComputeBoundsSingular(Equations, Fam, Positive, NotNull, vars, hyp, vminors, gendeg, lc, opts)
#    1046 nsols = [0, AdmissibleSolutions(nsols, len(Positive))]
#    1048 if len(Equations) + len(Fam) < len(vars):
# -> 1049     nsols2 = MSolveRealRoots(
#    1050         [rag_sat_var * pol - 1, *Equations, *minors, *Fam, *toadd, hyp - rag_sep_elem],
#    1051         [rag_sat_var, *vars, rag_sep_elem],
#    1052         [*Positive, *NotNull], opts
#    1053     )
#    1054 else:
#    1055     nsols2 = MSolveRealRoots(
#    1056         [rag_sat_var * pol - 1, *Equations, *minors, *Fam, *toadd, hyp - rag_sep_elem],
#    1057         [rag_sat_var, *vars, rag_sep_elem],
#    1058         [], opts
#    1059     )
#
# File ~/Documents/Documents - Andrew’s MacBook Air/Sage/RAGlib/msolve.py:491, in MSolveRealRoots(Fs, vs, G, opts)
#     487 vs = [R(v) for v in vs]
#     489 merged_opts = {**opts, "param": 1}
# --> 491 P, Qs, _ = MSolveParam(Fs, 0, vs, merged_opts)
#     492 Pd = P.derivative()
#     493 u_ = P.parent().gens()[0]
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# Out:
# set()

# %%
prod([])
# Out:
# 1

# %%
def PointsPerComponents(eqs, pos, ineqs, opts={}):
    _l = None
    newopts = None

    is_empty = opts.get("isempty", False)
    
    if not is_empty:
        return SemiAlgebraicSolve(eqs, pos, ineqs, opts);
    else:
        newopts = {
            k: 0 if k == "isempty" else v
            for k, v in opts.items()
        }
        return SemiAlgebraicSolve(eqs, pos, ineqs, newopts);
