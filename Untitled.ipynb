# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers import *
from msolve import *
from multi_modular import *

# %%
R.<x1,x2,x3,x4,x5,x6> = QQ[]

F = [
    x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1,
    x1**2 + 2*x2**2 + 2*x3**2 + 2*x4**2 + 2*x5**2 + 2*x6**2 - x1,
    2*x1*x2 + 2*x2*x3 + 2*x3*x4 + 2*x4*x5 + 2*x5*x6 - x2,
    x2**2 + 2*x1*x3 + 2*x2*x4 + 2*x3*x5 + 2*x4*x6 - x3,
    2*x2*x3 + 2*x1*x4 + 2*x2*x5 + 2*x3*x6 - x4,
    x3**2 + 2*x2*x4 + 2*x1*x5 + 2*x2*x6 - x5,
]
vars_list = [x1, x2, x3, x4, x5, x6]

#MSolveRealRoots(F, [x1,x2,x3,x4,x5,x6], [])

# %%
#MSolveGroebner(F, 0, [x1,x2,x3,x4,x5,x6])

# %%
#_[0]
# Out:
# x1 + 2*x2 + 2*x3 + 2*x4 + 2*x5 + 2*x6 - 1

# %%
#_.parent()
# Out:
# Multivariate Polynomial Ring in x1, x2, x3, x4, x5, x6 over Rational Field

# %%
R = PolynomialRing(QQ, ['x', 'y'], order='degrevlex')
x, y = R.gens()
result = SaturateIntersectMSolve(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)

# %%
result
# Out:
# [-2*y + 1, x]

# %%
result = SaturateIntersect(
    eqs1=[x**3 * (y - 2)],
    pol=x,
    eqs2=[y - 2],
    vs=[x, y],
)
# Out:
# Ideal (y - 2) of Multivariate Polynomial Ring in x, y over Rational Field

# %%
result
# Out:
# [y - 2]

# %%
from Raglib import *

# %%
SemiAlgebraicSolve([], [x], [x*y*z])
# Out:
# Equations: []
# pos: [x]
# nonzero: []
# Inequalities: [x]
# Inequations: [z*x*y]
#
#
# Equations: []
# pos: []
# nonzero: [z*x*y]
# Inequalities: [x]
# Inequations: [z*x*y]
#
# ++++
# Equations: []
# pos: [x]
# nonzero: [z*x*y]
# Inequalities: [x]
# Inequations: [z*x*y]
#
# ++++
# [{z: [1, 1], y: [1, 1], x: [1, 1]},
#  {x: [1, 1], y: [-2, -2], z: [1, 1]},
#  {x: [1/2, 1/2],
#   z: [-0.3138593383654928?, -0.3138593383654928?],
#   y: [-3.186140661634508?, -3.186140661634508?]},
#  {x: [1/2, 1/2],
#   z: [-3.186140661634508?, -3.186140661634508?],
#   y: [-0.3138593383654928?, -0.3138593383654928?]},
#  {x: [1/2, 1/2],
#   z: [0.2655644370746374?, 0.2655644370746374?],
#   y: [-3.765564437074638?, -3.765564437074638?]},
#  {x: [1/2, 1/2],
#   z: [-3.765564437074638?, -3.765564437074638?],
#   y: [0.2655644370746374?, 0.2655644370746374?]},
#  {x: [2.000000000000000?, 2.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [1/2, 1/2],
#   z: [0.7807764064044151?, 0.7807764064044151?],
#   y: [-1.280776406404415?, -1.280776406404415?]},
#  {x: [1/2, 1/2],
#   z: [-1.280776406404415?, -1.280776406404415?],
#   y: [0.7807764064044151?, 0.7807764064044151?]},
#  {x: [5.000000000000000?, 5.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [1/2, 1/2], z: [2, 2], y: [1/2, 1/2]},
#  {x: [1/2, 1/2], z: [1/2, 1/2], y: [2, 2]},
#  {x: [1/2, 1/2],
#   z: [2.850781059358213?, 2.850781059358213?],
#   y: [-0.3507810593582122?, -0.3507810593582122?]},
#  {x: [1/2, 1/2],
#   z: [-0.3507810593582122?, -0.3507810593582122?],
#   y: [2.850781059358213?, 2.850781059358213?]}]

# %%
#SemiAlgebraicSolve([], [], [x*y*z]); 0

# %%
from Raglib import *
test(R)
# Out:
# True

# %%
sign(-3)
# Out:
# -1

# %%
def PointsPerComponents(eqs, pos, ineqs, opts={}):
    _l = None
    newopts = None

    is_empty = opts.get("isempty", False)
    
    if not is_empty:
        return SemiAlgebraicSolve(eqs, pos, ineqs, opts);
    else:
        newopts = {
            k: 0 if k == "isempty" else v
            for k, v in opts.items()
        }
        return SemiAlgebraicSolve(eqs, pos, ineqs, newopts);

# %%
PointsPerComponents([x], [], [x*y*z])
# Out:
# ++++
# sys: [eps*rag_sat_var - 1, -z - y, -z^2*y - z*y^2 - eps, z^2 - y^2]
# vs: [rag_sat_var, eps, z, y]
#
# TODO:
# ineq: []
# [[x, (z, 1), (y, 1)]]

# %%
PointsPerComponents([], [x], [x*y*z])
# Out:
# ++++++++
# test: Here
# pos: [-z - y - 3]
#
#
# test: Here
# pos: [-z - y - 3]
#
#
# test: Here
# pos: [-z - y]
#
#
# test: Here
# pos: [-z - y]
#
#
# test: Here
# pos: [-z - y + 3]
#
#
# test: Here
# pos: [-z - y + 3]
# [{z: [1, 1], y: [1, 1], x: [1, 1]},
#  {x: [1/4, 1/4], y: [1/2, 1/2], z: [-7/4, -7/4]},
#  {x: [1, 1], y: [-1, -1], z: [-1, -1]},
#  {x: [3, 3], y: [-5, -5], z: [1, 1]},
#  {x: [1/4, 1/4], y: [-1, -1], z: [-1/4, -1/4]},
#  {x: [3/2, 3/2], y: [-7/2, -7/2], z: [1, 1]},
#  {x: [3/2, 3/2], y: [-9/2, -9/2], z: [2, 2]},
#  {x: [1, 1], y: [-5, -5], z: [3, 3]},
#  {x: [1, 1], y: [1, 1], z: [-1, -1]},
#  {x: [7/4, 7/4], y: [-1/2, -1/2], z: [-1/4, -1/4]},
#  {x: [3, 3], y: [-3, -3], z: [1, 1]},
#  {x: [1/4, 1/4], y: [1, 1], z: [-1/4, -1/4]},
#  {x: [5/8, 5/8], y: [1/4, 1/4], z: [1/8, 1/8]},
#  {x: [5/2, 5/2], y: [-7/2, -7/2], z: [2, 2]},
#  {x: [1/6, 1/6], y: [1/6, 1/6], z: [2/3, 2/3]},
#  {x: [3/2, 3/2], y: [-5/2, -5/2], z: [2, 2]},
#  {x: [1, 1], y: [-3, -3], z: [3, 3]},
#  {x: [-1.000000000000000?, -1.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [-5.000000000000000?, -5.000000000000000?], z: [1, 1], y: [1, 1]},
#  {x: [1/2, 1/2],
#   z: [-0.3138593383654928?, -0.3138593383654928?],
#   y: [-3.186140661634508?, -3.186140661634508?]},
#  {x: [1/2, 1/2],
#   z: [-3.186140661634508?, -3.186140661634508?],
#   y: [-0.3138593383654928?, -0.3138593383654928?]},
#  {x: [-17/2, -17/2],
#   z: [0.1882623085101004?, 0.1882623085101004?],
#   y: [5.311737691489900?, 5.311737691489900?]},
#  {x: [-17/2, -17/2],
#   z: [5.311737691489900?, 5.311737691489900?],
#   y: [0.1882623085101004?, 0.1882623085101004?]},
#  {x: [-19/2, -19/2],
#   z: [0.1576707807867546?, 0.1576707807867546?],
#   y: [6.342329219213246?, 6.342329219213246?]},
#  {x: [-19/2, -19/2],
#   z: [6.342329219213246?, 6.342329219213246?],
#   y: [0.1576707807867546?, 0.1576707807867546?]},
#  {x: [1/2, 1/2],
#   z: [0.2655644370746374?, 0.2655644370746374?],
#   y: [-3.765564437074638?, -3.765564437074638?]},
#  {x: [1/2, 1/2],
#   z: [-3.765564437074638?, -3.765564437074638?],
#   y: [0.2655644370746374?, 0.2655644370746374?]},
#  {x: [-17/2, -17/2],
#   z: [-0.1761749776799063?, -0.1761749776799063?],
#   y: [5.676174977679906?, 5.676174977679906?]},
#  {x: [-17/2, -17/2],
#   z: [5.676174977679906?, 5.676174977679906?],
#   y: [-0.1761749776799063?, -0.1761749776799063?]},
#  {x: [-19/2, -19/2],
#   z: [-0.1503676271838609?, -0.1503676271838609?],
#   y: [6.650367627183861?, 6.650367627183861?]},
#  {x: [-19/2, -19/2],
#   z: [6.650367627183861?, 6.650367627183861?],
#   y: [-0.1503676271838609?, -0.1503676271838609?]},
#  {x: [2.000000000000000?, 2.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [-2.000000000000000?, -2.000000000000000?], z: [1, 1], y: [1, 1]},
#  {x: [1/2, 1/2],
#   z: [0.7807764064044151?, 0.7807764064044151?],
#   y: [-1.280776406404415?, -1.280776406404415?]},
#  {x: [1/2, 1/2],
#   z: [-1.280776406404415?, -1.280776406404415?],
#   y: [0.7807764064044151?, 0.7807764064044151?]},
#  {x: [-1/2, -1/2],
#   z: [-0.7807764064044151?, -0.7807764064044151?],
#   y: [1.280776406404415?, 1.280776406404415?]},
#  {x: [-1/2, -1/2],
#   z: [1.280776406404415?, 1.280776406404415?],
#   y: [-0.7807764064044151?, -0.7807764064044151?]},
#  {x: [5.000000000000000?, 5.000000000000000?],
#   z: [-1.000000000000000?, -1.000000000000000?],
#   y: [-1.000000000000000?, -1.000000000000000?]},
#  {x: [1/2, 1/2], z: [2, 2], y: [1/2, 1/2]},
#  {x: [1/2, 1/2], z: [1/2, 1/2], y: [2, 2]},
#  {x: [-1/2, -1/2],
#   z: [0.3138593383654928?, 0.3138593383654928?],
#   y: [3.186140661634508?, 3.186140661634508?]},
#  {x: [-1/2, -1/2],
#   z: [3.186140661634508?, 3.186140661634508?],
#   y: [0.3138593383654928?, 0.3138593383654928?]},
#  {x: [1/2, 1/2],
#   z: [2.850781059358213?, 2.850781059358213?],
#   y: [-0.3507810593582122?, -0.3507810593582122?]},
#  {x: [1/2, 1/2],
#   z: [-0.3507810593582122?, -0.3507810593582122?],
#   y: [2.850781059358213?, 2.850781059358213?]},
#  {x: [-1/2, -1/2],
#   z: [-0.2655644370746374?, -0.2655644370746374?],
#   y: [3.765564437074638?, 3.765564437074638?]},
#  {x: [-1/2, -1/2],
#   z: [3.765564437074638?, 3.765564437074638?],
#   y: [-0.2655644370746374?, -0.2655644370746374?]}]
